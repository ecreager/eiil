# %% [markdown]
# <a href="https://colab.research.google.com/github/ecreager/eiil_dev/blob/public/notebooks/plot_cmnist_label_noise_sweep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Plot results from CMNIST label noise sweep experiments.

See  exps/cmnist.label_noise_sweep.sh for reproducing results.
"""
from collections import defaultdict
from glob import glob
import os
import pickle
from pprint import pprint

import matplotlib.pyplot as plt

def load_results(dirname):
  return pickle.load(open(os.path.join(dirname, 'metrics.p'), 'rb'))
  
def load_flags(dirname):
  return pickle.load(open(os.path.join(dirname, 'flags.p'), 'rb'))

# GLOB_PATTERNS = dict(
#   irm='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/irm',
#   erm='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/erm',
#   eiil='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/eiil',
#   eiil_cb='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/eiil_cb',
#   cb='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/cb',
#   gray='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28*/gray',
# )

GLOB_PATTERNS = dict(
  irm='/THIS/GLOB/PATTERN/FINDS/ALL/IRM/RESULTS/DIRS/*/irm',
  erm='/THIS/GLOB/PATTERN/FINDS/ALL/ERM/RESULTS/DIRS/*/erm',
  eiil='/THIS/GLOB/PATTERN/FINDS/ALL/EIIL/RESULTS/DIRS/*/eiil',
  eiil_cb='/THIS/GLOB/PATTERN/FINDS/ALL/EIIL-color-based/RESULTS/DIRS/*/eiil_cb',
  gray='/THIS/GLOB/PATTERN/FINDS/ALL/Grayscale/RESULTS/DIRS/*/gray',
  cb='/THIS/GLOB/PATTERN/FINDS/ALL/Color-based/RESULTS/DIRS/*/cb',
)

train_accs = defaultdict(dict)
test_accs = defaultdict(dict)
label_noises = set()

for k, v in GLOB_PATTERNS.items():
  print(k)
  pprint(glob(v))
  for dn in glob(v):
    try:
      results = load_results(dn)
      flags = load_flags(dn)
    except:
      print('no metrics or no flags found in', dn)
    label_noises.add(flags.label_noise)
    pprint(flags)
    train_accs[k][flags.label_noise] = results['Train accs']
    test_accs[k][flags.label_noise] = results['Test accs']

label_noises.remove(0.4)  # less interesting to look at super high noise case
label_noises.remove(0.45)  # less interesting to look at super high noise case
label_noises = sorted(label_noises)
# Out:
# irm
# ['/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/irm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/irm']
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, multiacc_prerun=False, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/irm', save_envs=False, split_majmin=False, steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.05, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.0, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.45, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/irm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# erm
# ['/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/erm',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/erm']
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, multiacc_prerun=False, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/erm', save_envs=False, split_majmin=False, steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.05, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.0, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.45, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=0, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/erm', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# eiil
# ['/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/eiil',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/eiil']
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# no metrics or no flags found in /scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/eiil
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.05, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.0, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.45, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/eiil', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# eiil_cb
# ['/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/eiil_cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/eiil_cb']
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# no metrics or no flags found in /scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.4/eiil_cb
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.05, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.0, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.45, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=True, color_based_eval=False, eiil=True, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/eiil_cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# cb
# ['/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/cb',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/cb']
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.05, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.0, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.45, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=True, eiil=False, grayscale_model=False, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=191257.18613115902, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/cb', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# gray
# ['/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/gray',
#  '/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/gray']
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.2, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.20/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.15, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.15/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.3, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.30/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.4, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.40/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.05, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.05/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.35, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.35/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.0, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.00/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.45, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.45/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.25, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.25/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)
# Namespace(color_based=False, color_based_eval=False, eiil=False, grayscale_model=True, hidden_dim=390, l2_regularizer_weight=0.00110794568, label_noise=0.1, lr=0.0004898536566546834, n_restarts=10, penalty_anneal_iters=190, penalty_weight=0.0, results_dir='/scratch/gobi1/creager/opt_env/cmnist/label_noise_sweep/2020-08-28--0.10/gray', steps=501, test_env__color_noise=0.9, train_env_1__color_noise=0.2, train_env_2__color_noise=0.1)

# %%
"""Compute confidence intervals to plot."""
means = {'train': defaultdict(list), 'test': defaultdict(list)}
upper_bounds = {'train': defaultdict(list), 'test': defaultdict(list)}
lower_bounds = {'train': defaultdict(list), 'test': defaultdict(list)}

import numpy as np
for method, v in train_accs.items():
  for sigma in label_noises:
    for dset, metrics in {'train': train_accs, 'test': test_accs}.items():
      mean = np.mean(metrics[method][sigma])
      std = np.std(metrics[method][sigma])
      means[dset][method].append(mean)
      upper_bounds[dset][method].append(mean + std)
      lower_bounds[dset][method].append(mean - std)


pprint(means)
# Out:
# {'test': defaultdict(<class 'list'>,
#                      {'cb': [0.1000199981033802,
#                              0.10012999698519706,
#                              0.09865999817848206,
#                              0.0988399975001812,
#                              0.1001499980688095,
#                              0.09878999814391136,
#                              0.09963999763131141,
#                              0.10030999779701233],
#                       'eiil': [0.7090499818325042,
#                                0.421919983625412,
#                                0.4314099907875061,
#                                0.6683499813079834,
#                                0.7062399864196778,
#                                0.6940499901771545,
#                                0.6230899930000305,
#                                0.5715399861335755],
#                       'eiil_cb': [0.9449199736118317,
#                                   0.8696799755096436,
#                                   0.8338599801063538,
#                                   0.7812799870967865,
#                                   0.7244599819183349,
#                                   0.6678599894046784,
#                                   0.6196299850940704,
#                                   0.5679899871349334],
#                       'erm': [0.9172199666500092,
#                               0.7719999849796295,
#                               0.5859599828720092,
#                               0.38434998989105223,
#                               0.22362999469041825,
#                               0.1394599959254265,
#                               0.10860999822616577,
#                               0.1024799957871437],
#                       'gray': [0.9782699763774871,
#                                0.9283899784088134,
#                                0.8774399816989898,
#                                0.8267999768257142,
#                                0.7776999771595001,
#                                0.7273899793624878,
#                                0.673389983177185,
#                                0.6224399864673614],
#                       'irm': [0.8275299727916717,
#                               0.8628299772739411,
#                               0.8309799790382385,
#                               0.7815899729728699,
#                               0.7122699856758118,
#                               0.6528799831867218,
#                               0.6297999799251557,
#                               0.5810999929904938]}),
#  'train': defaultdict(<class 'list'>,
#                       {'cb': [0.8502159774303436,
#                               0.849539977312088,
#                               0.8507299721240997,
#                               0.8501559734344483,
#                               0.8488539755344391,
#                               0.8504519820213318,
#                               0.8495599746704101,
#                               0.8498919785022736],
#                        'eiil': [0.9371594190597534,
#                                 0.8174977004528046,
#                                 0.776884400844574,
#                                 0.7473608434200287,
#                                 0.7495961129665375,
#                                 0.7369162082672119,
#                                 0.7092883110046386,
#                                 0.681495076417923],
#                        'eiil_cb': [0.9610876441001892,
#                                    0.9240280210971832,
#                                    0.8849621295928956,
#                                    0.8420023024082184,
#                                    0.7999043703079224,
#                                    0.7534381687641144,
#                                    0.7192284405231476,
#                                    0.680934053659439],
#                        'erm': [0.9897419691085816,
#                                0.9479099810123444,
#                                0.917331975698471,
#                                0.8960599780082703,
#                                0.877929973602295,
#                                0.8630419731140136,
#                                0.8544179797172546,
#                                0.8511299967765809],
#                        'gray': [0.9870419800281525,
#                                 0.9383739709854126,
#                                 0.8904179811477662,
#                                 0.8436359763145447,
#                                 0.7978099703788757,
#                                 0.7530679821968078,
#                                 0.7139159798622131,
#                                 0.6774439871311188],
#                        'irm': [0.9653079748153687,
#                                0.9221599817276,
#                                0.8707279741764069,
#                                0.8101959824562073,
#                                0.7565379738807678,
#                                0.7063279867172241,
#                                0.6514319837093353,
#                                0.6057579755783081]})}

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import colorConverter as cc
import numpy as np
import seaborn as sns

TITLE_FONTSIZE = 16
AXIS_FONTSIZE = 16
LEGEND_FONTSIZE = 9
FIGSIZE = (7, 4)
SHADING_OPACITY = .5  # how opaque should the uncertainty fills be
LATEX_SYMBOLS = dict(
    erm=r'\textsc{ERM}',
    cb=r'$\Phi_{Color}$',
    gray=r'\textsc{Grayscale}',
    irm=r'\textsc{IRM}($e_{\textsc{HC}}$)',
    eiil=r'\textsc{IRM}($e_{\textsc{EIIL}}| \tilde \Phi = \Phi_{ERM}$)',
    eiil_cb=r'\textsc{IRM}($e_{\textsc{EIIL}}| \tilde \Phi = \Phi_{Color}$)',
)


class LegendObject(object):
    def __init__(self, facecolor='red', edgecolor='white', dashed=False):
        self.facecolor = facecolor
        self.edgecolor = edgecolor
        self.dashed = dashed
 
    def legend_artist(self, legend, orig_handle, fontsize, handlebox):
        x0, y0 = handlebox.xdescent, handlebox.ydescent
        width, height = handlebox.width, handlebox.height
        patch = mpatches.Rectangle(
            # create a rectangle that is filled with color
            [x0, y0], width, height, facecolor=self.facecolor,
            # and whose edges are the faded color
            edgecolor=self.edgecolor, lw=3)
        handlebox.add_artist(patch)
 
        # if we're creating the legend for a dashed line,
        # manually add the dash in to our rectangle
        if self.dashed:
            patch1 = mpatches.Rectangle(
                [x0 + 2*width/5, y0], width/5, height, facecolor=self.edgecolor,
                transform=handlebox.get_transform())
            handlebox.add_artist(patch1)
 
        return patch
 
 
def plot_mean_and_CI(label_noise, mean, lb, ub, color_mean=None, color_shading=None):
    # plot the shaded range of the confidence intervals
    plt.fill_between(label_noise, ub, lb,
                     color=color_shading, alpha=.5)
    # plot the mean on top
    plt.plot(label_noise, mean, color=color_mean)
 
# plot the data
a = lambda x: np.array(x)
bg = np.array([1, 1, 1])  # background of the legend is white
for dset in ('train', 'test'):
  from itertools import cycle
  handler_map = dict()
  colors = iter(sns.color_palette("colorblind", len(GLOB_PATTERNS)))
  legend_names = []
  plt.figure(figsize=FIGSIZE)
  for i, method in enumerate(means[dset].keys()):
    legend_names.append(LATEX_SYMBOLS[method])
    color = next(colors)
    color_faded = (np.array(cc.to_rgb(color)) + bg) * SHADING_OPACITY
    handler_map[i] = LegendObject(color, color_faded)
    plot_mean_and_CI(label_noises, 
                     a(means[dset][method]), 
                     a(lower_bounds[dset][method]), 
                     a(upper_bounds[dset][method]),
                     color_mean=color, color_shading=color_faded)
 
  plt.legend(range(len(legend_names)), legend_names, handler_map=handler_map,
             loc='lower left' if dset == 'train' else 'lower right', 
             fontsize=LEGEND_FONTSIZE)
  plt.xlabel(r'Label noise $\sigma_y$', fontsize=AXIS_FONTSIZE)
  if dset == 'train':
    plt.ylabel('Accuracy', fontsize=AXIS_FONTSIZE)
  plt.tight_layout()
  plt.ylim((0., 1.))
  plt.grid()
  plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
